# %%
import pyuvsim

# %%
pyuvsim.uvsim.run_uvsim("/Users/ronniyjoseph/Sync/MSI_Fellowship/Arpeggio/settings.yaml", return_uv=True)
# Out:
# Nbls: 3
# Ntimes: 10000
# Nfreqs: 1
# Nsrcs: 1
# Tasks:  30000.0
# ...
# 1.00% completed. 0:00:01.247807  elapsed. 0:02:03.950222 remaining.
#
# 2.00% completed. 0:00:02.343352  elapsed. 0:01:55.019857 remaining.
#
# 3.00% completed. 0:00:03.448300  elapsed. 0:01:51.622894 remaining.
#
# 4.00% completed. 0:00:04.548287  elapsed. 0:01:49.253727 remaining.
#
# 5.00% completed. 0:00:06.046652  elapsed. 0:01:54.967065 remaining.
#
# 6.00% completed. 0:00:07.145770  elapsed. 0:01:52.016599 remaining.
#
# 7.00% completed. 0:00:08.246165  elapsed. 0:01:49.612316 remaining.
#
# 8.00% completed. 0:00:09.357336  elapsed. 0:01:47.658121 remaining.
#
# 9.00% completed. 0:00:10.841562  elapsed. 0:01:49.664870 remaining.
#
# 10.00% completed. 0:00:12.138621  elapsed. 0:01:49.288065 remaining.
#
# 11.00% completed. 0:00:13.242179  elapsed. 0:01:47.177759 remaining.
#
# 12.00% completed. 0:00:14.354983  elapsed. 0:01:45.303114 remaining.
#
# ...

# %% [markdown]
# ## Let's work with this output

# %%
import os
from pyuvdata import UVData
from pyuvdata.data import DATA_PATH
from matplotlib import pyplot as plt
import numpy as np

# %%
UV = UVData()

# %%
UV.data_array *=0
from arpeggio.perturbate import ThermalNoise
from ..arpeggio import arpeggio
os.getcwd()
